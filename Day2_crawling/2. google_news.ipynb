# %% [markdown]
# ### 1. 구글 뉴스 클리핑 (실습)
#
# #### 10페이지까지 크롤링

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

browser = webdriver.Chrome()
browser.get('https://www.google.com/search?q=%EC%9E%90%EB%8F%99%ED%99%94&hl=ko&tbm=nws&source=lnt&tbs=qdr:w&sa=X&ved=2ahUKEwja2vHE-_z6AhVC4GEKHYpGBEAQpwV6BAgCEBs&biw=939&bih=770&dpr=1.5')

# %%
search_word = input("크롤링하고자 하는 단어를 입력하세요.")
page = int(input("크롤링하고자 하는 페이지수를 입력하세요."))
# Out:
# 크롤링하고자 하는 단어를 입력하세요.당근마켓
# 크롤링하고자 하는 페이지수를 입력하세요.10

# %%
title = []

for i in range(0, page*10, 10):
    url = 'https://www.google.com/search?q=%EB%8B%B9%EA%B7%BC%EB%A7%88%EC%BC%93&hl=ko&tbs=qdr:w&tbm=nws&ei=QbNYY-CUDsSJoAS796ioDw&start='+str(i)+'&sa=N&ved=2ahUKEwigudipg_36AhXEBIgKHbs7CvU4ChDy0wN6BAgBEAQ&biw=939&bih=770&dpr=1.5'
    browser.get(url)
    time.sleep(3)
    browser.implicitly_wait(10)
    
    titles = browser.find_elements(By.CLASS_NAME, 'mCBkyc')
    for j in titles:
        title.append(j.text.replace(',',''))
title
# Out:
# ['[머니네버슬립] 당근마켓이 상장한다면? 똑닮은 미국 상장사 ...',
#  "'당근마켓' 커뮤니티가 흥하는 이유",
#  '당근마켓 "고물가에 반찬가게 비즈프로필 조회수 2배 뛰어"',
#  '당근마켓 C/L 중고거래 불가… 안경사 반색',
#  "'고물가에 집밥족 늘어'…당근마켓 비즈 프로필 이용률 137%↑ - 서울경제",
#  "카카오 먹통 후 '안정성' 대두…배민·당근마켓도 '셧다운' 대비",
#  "단골 관리 도우미에 나선 'IT 스타트업'",
#  '당근마켓 비즈프로필 누적 이용자 수 2000만명 돌파',
#  '"한번 입은 골프옷 팝니다" 이자폭탄에 중고거래 폭발',
#  '디지털마케팅 스타트업에서부터 소상공인까지 시장 성공에 ...',
#  "'단골 손님' 이끄는 고객 관리 비결은?' IT업계 채널톡 등 단골 ...",
#  '제이스톡 비상장 주식계 당근마켓 연다…리뉴얼 앱 출시',
#  '비싼 옷 엄청 사들이더니…"테니스 칠래요" 떠나는 MZ골퍼들',
#  '품귀라던 골프채 쏟아진다',
#  '‘노코드 개발’ 된다는데…장병규는 왜 ‘SW교육’ 또 만드나',
#  "'서카포연고' 나와야 유리한 투자유치... 혁신보단 학벌",
#  '보이스 피싱 예방 금융기관 창구 직원 감사장 수여',
#  '매출 올려주는 핵심은 바로 ‘단골’.. 단골 고객 만들어 주는 IT ...',
#  '콘서트도 아닌데 웃돈 6배…단풍명소 입장권 싹쓸이한 암표상',
#  '고양이 집사가 당근 거래 못하는 이유.."얘는 못판다옹!"',
#  '[에딧머니] [임하영의 해시태그] 네이버 롯데 신세계가 한눈에 ...',
#  "과기정통부·NIA “한국코드페어 성료”…'청소년 디지털 기술로 ...",
#  '스타벅스 1000원 싸게 마신다…고물가에 기프티콘 플랫폼 급성장',
#  '네이버의 美 포쉬마크 인수 5년 뒤가 궁금하다',
#  "5개월 합숙…장병규표 '코딩사관학교' 닻 올렸다 - 서울경제",
# ...

# %%
# 참고 (page down)
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %% [markdown]
# ### 2. 구글 플레이 스토어 크롤링 (실습)
# #### 리뷰 데이터 크롤링

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
browser.find_element(By.XPATH, '//*[@id="yDmH0d"]/c-wiz[3]/div/div/div[1]/div[2]/div/div[1]/c-wiz[4]/section/header/div/div[2]/button').click()

# %%
app = input("검색하고자 하는 앱을 입력하세요.")

url = 'https://play.google.com/store/search?q='+app+'&c=apps'
browser.get(url)
browser.find_element(By.CLASS_NAME, 'Si6A0c').click()
time.sleep(3)
browser.find_element(By.XPATH, '//*[@id="yDmH0d"]/c-wiz[3]/div/div/div[1]/div[2]/div/div[1]/c-wiz[4]/section/header/div/div[2]/button').click()
# Out:
# 검색하고자 하는 앱을 입력하세요.당근마켓

# %%
reviews = browser.find_elements(By.CLASS_NAME, 'RHo1pe')
review = []

for i in reviews:
    review.append(i.find_element(By.CLASS_NAME, 'h3YV2d').text)
    
review
# Out:
# ['정말 잘 사용하고 있습니다. 특히 키워드 알림을 너무 잘 사용하고 있는데요. 특정 단어들은 동작하지 않아서 글을 남깁니다. 스퀘어가든,전천당을 구할려고 검색을 하면 나오나 키워드 알림 등록으로 하면 알림이 안옵니다. 물론 갤럭시 모빌 유모차등 다른 단어들은 잘옵니다. 자동으로 필터링되는건지 이 부분만 불편하네요',
#  '소리모드인 경우에만 당근알림 정상 작동. 진동모드에서 당근진동알림 작동안됨. 블루투스 이어폰으로 교보문고 앱 TTS 읽어주기 기능 이용시 당근알림 안됨. 확인부탁합니다. 당근앱 알림/진동허용. 앱 절전모드 진입해제, 재로그인 등 당근 알림 안됨 조치 방법 모두 시도했으나 동일. 예전버전에서는 블루투스 TTS기능 사용중에도 당근알림이 잘 왔으나 몇 개월 전부터 작동안됨. 휴대폰 살정은 그대로이나 당근 업데이트 후 작동 안되는 것으로 보임.',
#  '잘 쓰고 있습니다 사용하면서 불편한 점이 있었는데 개선될 수 있으면 좋겠습니다! (1) 근처 동네 4개가 아니라 저희 동 1개만 볼 수 있었으면 좋겠어요. 옆 동네까지 가려면 버스 타고 30분이 걸립니다. 판매자 정보에 xx x동이 아니라 xx동이라고만 뜨면 거래가 꺼려지네요 (2) 관심목록 폴더 기능이 생겼으면 좋겠어요. 관심목록이 많아지니까 보기 너무너무너무 불편해요. 관심 누른 목록 최근순/최신 끌올된 순으로 볼 수 있는 정도로라도요',
#  '갑자기 어제부턴가 홈 화면에서 물품 리스트가 시간순이 아닌 뒤죽박죽 랜덤으로 정렬됩니다. 몇 번 새로고침을 해도 시간은 몇 초전부터 몇일전까지 완전 뒤죽박죽이고 특정 물품이 계속 최상단에 고정되기도 해요 이미 거래완료 된 물품도 리스트에 섞여나오니 보기가 불편합니다 다른 사람 폰에서도 그러네요',
# ...

# %%
browser.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
scrollable_popup = browser.find_element(By.XPATH, '//*[@id="yDmH0d"]/div[5]/div[2]/div/div/div/div/div[2]/div')
browser.execute_script("arguments[0].scrollTop = arguments[0].scrollHeight", scrollable_popup)

# %%
browser.find_element(By.CLASS_NAME, 'odk6He').text
# Out:
# 'Han Jinsu\nmore_vert\n2022년 9월 6일\n정말 잘 사용하고 있습니다. 특히 키워드 알림을 너무 잘 사용하고 있는데요. 특정 단어들은 동작하지 않아서 글을 남깁니다. 스퀘어가든,전천당을 구할려고 검색을 하면 나오나 키워드 알림 등록으로 하면 알림이 안옵니다. 물론 갤럭시 모빌 유모차등 다른 단어들은 잘옵니다. 자동으로 필터링되는건지 이 부분만 불편하네요\n사용자 164명이 이 리뷰가 유용하다고 평가함\n이 리뷰가 유용했나요?\n예\n아니요\nDanggeun Market Inc.\n2022년 9월 6일\nHan Jinsu님 안녕하세요. 당근마켓 서비스를 이용하시면서 불편함을 겪으신 것 같아요. 먼저 이용에 불편함을 드려 죄송해요. 이곳에서는 구체적인 계정 확인 및 처리에 어려움이 있어요. [나의당근>자주묻는질문>문의하기]를 통해 오류 상황에 대해 글 남겨 주세요. 담당 부서에서 확인 후, 필요한 도움 드릴게요. 감사합니다. 당근마켓 팀 드림\n조태희\nmore_vert\n2022년 9월 29일\n소리모드인 경우에만 당근알림 정상 작동. 진동모드에서 당근진동알림 작동안됨. 블루투스 이어폰으로 교보문고 앱 TTS 읽어주기 기능 이용시 당근알림 안됨. 확인부탁합니다. 당근앱 알림/진동허용. 앱 절전모드 진입해제, 재로그인 등 당근 알림 안됨 조치 방법 모두 시도했으나 동일. 예전버전에서는 블루투스 TTS기능 사용중에도 당근알림이 잘 왔으나 몇 개월 전부터 작동안됨. 휴대폰 살정은 그대로이나 당근 업데이트 후 작동 안되는 것으로 보임.\n사용자 118명이 이 리뷰가 유용하다고 평가함\n이 리뷰가 유용했나요?\n예\n아니요\nDanggeun Market Inc.\n2022년 9월 30일\n조태희님 안녕하세요. 당근마켓 서비스를 이용하시면서 불편함을 겪으신 것 같아요. 먼저 이용에 불편함을 드려 죄송해요. 이곳에서는 구체적인 계정 확인 및 처리에 어려움이 있어요. [나의당근>자주묻는질문>문의하기]를 통해 오류 상황에 대해 글 남겨 주세요. 담당 부
# ...
